# %% [markdown]
# <a href="https://colab.research.google.com/github/G0nkly/Ready-Set-Prophecy/blob/main/ARIMA/ARIMA_Melbourne_temps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv"

df = pd.read_csv(url, parse_dates=["Date"])
df = df.rename(columns={"Date": "date", "Temp": "temp_min"})
df = df.sort_values("date")

df.head()
# Out:
#         date  temp_min
# 0 1981-01-01      20.7
# 1 1981-01-02      17.9
# 2 1981-01-03      18.8
# 3 1981-01-04      14.6
# 4 1981-01-05      15.8

# %%
df.set_index("date", inplace=True)
df = df.asfreq("D")

assert not df.isnull().all().item(), "Missing values detected"
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3652 entries, 1981-01-01 to 1990-12-31
# Freq: D
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   temp_min  3650 non-null   float64
# dtypes: float64(1)
# memory usage: 57.1 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3652 entries, 1981-01-01 to 1990-12-31
# Freq: D
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   temp_min  3650 non-null   float64
# dtypes: float64(1)
# memory usage: 57.1 KB

# %%
df.head()
# Out:
#             temp_min
# date
# 1981-01-01      20.7
# 1981-01-02      17.9
# 1981-01-03      18.8
# 1981-01-04      14.6
# 1981-01-05      15.8

# %%
df.head(10)
# Out:
#             temp_min
# date
# 1981-01-01      20.7
# 1981-01-02      17.9
# 1981-01-03      18.8
# 1981-01-04      14.6
# 1981-01-05      15.8
# 1981-01-06      15.8
# 1981-01-07      15.8
# 1981-01-08      17.4
# 1981-01-09      21.8
# 1981-01-10      20.0

# %%
df.isna().any().any()
# Out:
# np.True_

# %%
df.isnull().all(1)
# Out:
# date
# 1981-01-01    False
# 1981-01-02    False
# 1981-01-03    False
# 1981-01-04    False
# 1981-01-05    False
#               ...
# 1990-12-27    False
# 1990-12-28    False
# 1990-12-29    False
# 1990-12-30    False
# 1990-12-31    False
# Freq: D, Length: 3652, dtype: bool

# %%
df.isnull().all(1).item()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1301151822.py in <cell line: 0>()
# ----> 1 df.isnull().all(1).item()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in item(self)
#     416         if len(self) == 1:
#     417             return next(iter(self))
# --> 418         raise ValueError("can only convert an array of size 1 to a Python scalar")
#     419
#     420     @property
#
# ValueError: can only convert an array of size 1 to a Python scalar
